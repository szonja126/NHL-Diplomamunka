# %%
import requests
import pickle
import pandas as pd
import json as js
import matplotlib.pyplot as plt

# %%
players_df = pd.read_csv('players_df.csv')
teams_df = pd.read_csv('teams_df.csv')
teams_df = teams_df.drop_duplicates()
teams_df = teams_df.sort_values('id')
games_df = pd.read_csv('games_df.csv')
events_df = pd.read_csv('events_df.csv')
#players_df
#teams_df
#games_df
events_df

# %%
avg_age = pd.DataFrame()
avg_age = round(players_df.groupby('teamID')['currentAge'].mean(),1).sort_values()
teamsname = teams_df[['id','name']]
#avg_age = avg_age.to_frame()
#avg_age.dtypes
#avg_age.join(teams_df, on='teamID', how='left', lsuffix='teamID', rsuffix='id')
#teamsname
agebyteams = pd.merge(left=avg_age, right=teamsname, left_on='teamID', right_on='id', how='left')
agebyteams
# Out:
#     currentAge  id                   name
# 0         28.2   3       New York Rangers
# 1         28.3   7         Buffalo Sabres
# 2         28.3  29  Columbus Blue Jackets
# 3         28.4  12    Carolina Hurricanes
# 4         28.4  52          Winnipeg Jets
# 5         28.7  10    Toronto Maple Leafs
# 6         28.7   1      New Jersey Devils
# 7         28.8  21     Colorado Avalanche
# 8         29.1   4    Philadelphia Flyers
# 9         29.1  24          Anaheim Ducks
# 10        29.2   9        Ottawa Senators
# 11        29.3   8     Montréal Canadiens
# 12        29.3  16     Chicago Blackhawks
# 13        29.5  23      Vancouver Canucks
# 14        29.5   5    Pittsburgh Penguins
# 15        29.6  20         Calgary Flames
# 16        29.7  53        Arizona Coyotes
# 17        29.7  22        Edmonton Oilers
# 18        29.8  13       Florida Panthers
# 19        29.9  14    Tampa Bay Lightning
# 20        30.0  26      Los Angeles Kings
# 21        30.1  17      Detroit Red Wings
# 22        30.1   2     New York Islanders
# 23        30.2  19        St. Louis Blues
# 24        30.5  54   Vegas Golden Knights
# 25        30.6   6          Boston Bruins
# 26        30.6  30         Minnesota Wild
# 27        30.8  15    Washington Capitals
# 28        30.9  28        San Jose Sharks
# 29        31.1  18    Nashville Predators
# 30        31.2  25           Dallas Stars

# %%
playersage = players_df[['id','currentAge']]
playersage = playersage.drop_duplicates()
playersage = playersage.drop(columns=['id'])
plt.hist(playersage)
plt.title('Jatekosok eletkoranak megoszlasa')
plt.xlabel('Kor')
# Out:
# Text(0.5, 0, 'Kor')

# %%
teams_df
# Out:
#     id                   name              link abbreviation triCode  \
# 25   1      New Jersey Devils   /api/v1/teams/1          NJD     NJD
# 27   2     New York Islanders   /api/v1/teams/2          NYI     NYI
# 11   3       New York Rangers   /api/v1/teams/3          NYR     NYR
# 31   4    Philadelphia Flyers   /api/v1/teams/4          PHI     PHI
# 13   5    Pittsburgh Penguins   /api/v1/teams/5          PIT     PIT
# 18   6          Boston Bruins   /api/v1/teams/6          BOS     BOS
# 12   7         Buffalo Sabres   /api/v1/teams/7          BUF     BUF
# 14   8     Montréal Canadiens   /api/v1/teams/8          MTL     MTL
# 0    9        Ottawa Senators   /api/v1/teams/9          OTT     OTT
# 1   10    Toronto Maple Leafs  /api/v1/teams/10          TOR     TOR
# 15  12    Carolina Hurricanes  /api/v1/teams/12          CAR     CAR
# 8   13       Florida Panthers  /api/v1/teams/13          FLA     FLA
# 9   14    Tampa Bay Lightning  /api/v1/teams/14          TBL     TBL
# 2   15    Washington Capitals  /api/v1/teams/15          WSH     WSH
# 30  16     Chicago Blackhawks  /api/v1/teams/16          CHI     CHI
# 48  17      Detroit Red Wings  /api/v1/teams/17          DET     DET
# 17  18    Nashville Predators  /api/v1/teams/18          NSH     NSH
# 3   19        St. Louis Blues  /api/v1/teams/19          STL     STL
# 20  20         Calgary Flames  /api/v1/teams/20          CGY     CGY
# 21  21     Colorado Avalanche  /api/v1/teams/21          COL     COL
# 5   22        Edmonton Oilers  /api/v1/teams/22          EDM     EDM
# 4   23      Vancouver Canucks  /api/v1/teams/23          VAN     VAN
# 23  24          Anaheim Ducks  /api/v1/teams/24          ANA     ANA
# 19  25           Dallas Stars  /api/v1/teams/25          DAL     DAL
# 56  26      Los Angeles Kings  /api/v1/teams/26          LAK     LAK
# 6   28        San Jose Sharks  /api/v1/teams/28          SJS     SJS
# 29  29  Columbus Blue Jackets  /api/v1/teams/29          CBJ     CBJ
# 16  30         Minnesota Wild  /api/v1/teams/30          MIN     MIN
# 10  52          Winnipeg Jets  /api/v1/teams/52          WPG     WPG
# 22  53        Arizona Coyotes  /api/v1/teams/53          ARI     ARI
# 7   54   Vegas Golden Knights  /api/v1/teams/54          VGK     VGK
#
#           teamName  locationName  firstYearOfPlay     shortName  active
# 25          Devils    New Jersey             1982    New Jersey    True
# 27       Islanders      New York             1972  NY Islanders    True
# 11         Rangers      New York             1926    NY Rangers    True
# 31          Flyers  Philadelphia             1967  Philadelphia    True
# 13        Penguins    Pittsburgh             1967    Pittsburgh    True
# 18          Bruins        Boston             1924        Boston    True
# 12          Sabres       Buffalo             1970       Buffalo    True
# 14       Canadiens      Montréal             1917      Montréal    True
# 0         Senators        Ottawa             1992        Ottawa    True
# 1      Maple Leafs       Toronto             1926       Toronto    True
# 15      Hurricanes      Carolina             1997      Carolina    True
# 8         Panthers       Florida             1993       Florida    True
# 9        Lightning     Tampa Bay             1992     Tampa Bay    True
# 2         Capitals    Washington             1974    Washington    True
# 30      Blackhawks       Chicago             1926       Chicago    True
# 48       Red Wings       Detroit             1932       Detroit    True
# 17       Predators     Nashville             1998     Nashville    True
# 3            Blues     St. Louis             1967      St Louis    True
# 20          Flames       Calgary             1980       Calgary    True
# 21       Avalanche      Colorado             1995      Colorado    True
# 5           Oilers      Edmonton             1979      Edmonton    True
# 4          Canucks     Vancouver             1970     Vancouver    True
# 23           Ducks       Anaheim             1993       Anaheim    True
# 19           Stars        Dallas             1993        Dallas    True
# 56           Kings   Los Angeles             1967   Los Angeles    True
# 6           Sharks      San Jose             1991      San Jose    True
# 29    Blue Jackets      Columbus             2000      Columbus    True
# 16            Wild     Minnesota             2000     Minnesota    True
# 10            Jets      Winnipeg             2011      Winnipeg    True
# 22         Coyotes       Arizona             2014       Arizona    True
# 7   Golden Knights         Vegas             2017         Vegas    True
